# %%
import pandas as pd

df_train = pd.read_csv("/Users/sumrubektas/Desktop/train.csv")
df_train.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# # ✈️ Airline Passenger Satisfaction Analysis Report

# %%
df_test = pd.read_csv("/Users/sumrubektas/Desktop/test.csv")
df_test.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %% [markdown]
# ## Project Overview
#
# The aim of this project is to analyze the factors that influence airline passenger satisfaction using a dataset of flight-related and service-related variables.
#
# Dataset: **Airline Passenger Satisfaction Dataset**
# Rows: **103,904**
# Columns: **24**

# %%
# Statistical summary for numerical variables
df_train.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# ## Statistical Summary of Numerical Features
#
# Key observations:
#
# - **Average Age**: 39.3 (range: 7 to 85)
# - **Average Flight Distance**: 1,189 km
# - Most service ratings (e.g., Inflight Service, Cleanliness) are between 2 and 5.
# - Delay times (departure/arrival) show right-skewed distributions.

# %%
import pandas as pd

df_train = pd.read_csv("/Users/sumrubektas/Desktop/train.csv")
df_train.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
# Drop unnecessary columns if they exist, ignore if not
df_train = df_train.drop(columns=['Unnamed: 0', 'id'], errors='ignore')

# Check data types of columns
print(df_train.dtypes)

# Separate numeric and categorical columns
numeric_cols = df_train.select_dtypes(include=['number']).columns
categorical_cols = df_train.select_dtypes(include=['object']).columns

print("Numeric columns:", numeric_cols)
print("Categorical columns:", categorical_cols)
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %%
missing_values = df_train.isnull().sum()
missing_percentage = (missing_values / len(df_train)) * 100

missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
})

missing_df = missing_df[missing_df['Missing Values'] > 0]
missing_df
# Out:
#                           Missing Values  Percentage (%)
# Arrival Delay in Minutes             310        0.298352

# %% [markdown]
# ## Missing Value Analysis
#
# - The column **"Arrival Delay in Minutes"** had **310 missing values**.
# - These missing values were filled using the **median** of the column.
# - After imputation, **there are no missing values** remaining in the dataset.

# %%
median_arrival_delay = df_train['Arrival Delay in Minutes'].median()
df_train['Arrival Delay in Minutes'] = df_train['Arrival Delay in Minutes'].fillna(median_arrival_delay)

# Check if there are any missing values left
print(df_train['Arrival Delay in Minutes'].isnull().sum())
# Out:
# 0

# %%
Q1 = df_train['Arrival Delay in Minutes'].quantile(0.25)
Q3 = df_train['Arrival Delay in Minutes'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df_train[(df_train['Arrival Delay in Minutes'] < lower_bound) | (df_train['Arrival Delay in Minutes'] > upper_bound)]

print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 13954

# %%
df_train['Arrival Delay in Minutes'] = df_train['Arrival Delay in Minutes'].apply(
    lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x)
)

# %%
outliers_after = df_train[(df_train['Arrival Delay in Minutes'] < lower_bound) | (df_train['Arrival Delay in Minutes'] > upper_bound)]
print(f"Number of outliers after capping: {len(outliers_after)}")
# Out:
# Number of outliers after capping: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(df_train['Arrival Delay in Minutes'], bins=30, kde=True)
plt.title('Arrival Delay in Minutes - Histogram')

plt.subplot(1,2,2)
sns.boxplot(x=df_train['Arrival Delay in Minutes'])
plt.title('Arrival Delay in Minutes - Boxplot')

plt.show()

# %%
# Select numeric columns
numeric_columns = df_train.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_columns:
    Q1 = df_train[col].quantile(0.25)
    Q3 = df_train[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Calculate number of outliers
    outlier_count = df_train[(df_train[col] < lower_bound) | (df_train[col] > upper_bound)].shape[0]
    print(f"Number of outliers in column {col}: {outlier_count}")
    
    # Cap the outliers
    df_train[col] = df_train[col].apply(
        lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x)
    )
# Out:
# Number of outliers in column Age: 0
# Number of outliers in column Flight Distance: 2291
# Number of outliers in column Inflight wifi service: 0
# Number of outliers in column Departure/Arrival time convenient: 0
# Number of outliers in column Ease of Online booking: 0
# Number of outliers in column Gate location: 0
# Number of outliers in column Food and drink: 0
# Number of outliers in column Online boarding: 0
# Number of outliers in column Seat comfort: 0
# Number of outliers in column Inflight entertainment: 0
# Number of outliers in column On-board service: 0
# Number of outliers in column Leg room service: 0
# Number of outliers in column Baggage handling: 0
# Number of outliers in column Checkin service: 12891
# Number of outliers in column Inflight service: 0
# Number of outliers in column Cleanliness: 0
# Number of outliers in column Departure Delay in Minutes: 14529
# Number of outliers in column Arrival Delay in Minutes: 0

# %% [markdown]
# ## Outlier Detection
#
# - Outliers were detected using the **IQR (Interquartile Range)** method.
# - Most outliers were found in delay-related columns.
# - Due to the real-world nature of flight data (e.g., unexpected delays), these outliers were **retained** and not removed.

# %%
numeric_columns = df_train.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_columns:
    print(f"--- {col} ---")
    print("Summary statistics (after capping):")
    print(df_train[col].describe())
    print("\n")
# Out:
# --- Age ---
# Summary statistics (after capping):
# count    103904.000000
# mean         39.379706
# std          15.114964
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64
#
#
# --- Flight Distance ---
# Summary statistics (after capping):
# count    103904.000000
# mean       1186.133927
# std         988.126724
# min          31.000000
# 25%         414.000000
# 50%         843.000000
# 75%        1743.000000
# max        3736.500000
# Name: Flight Distance, dtype: float64
#
#
# --- Inflight wifi service ---
# Summary statistics (after capping):
# count    103904.000000
# mean          2.729683
# std           1.327829
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: Inflight wifi service, dtype: float64
#
#
# --- Departure/Arrival time convenient ---
# Summary statistics (after capping):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in numeric_columns:
    plt.figure(figsize=(12,4))
    
    plt.subplot(1,2,1)
    sns.histplot(df_train[col], bins=30, kde=True)
    plt.title(f"{col} - Histogram")
    
    plt.subplot(1,2,2)
    sns.boxplot(x=df_train[col])
    plt.title(f"{col} - Boxplot")
    
    plt.show()

# %% [markdown]
# ## Data Visualization Summary
#
# ### Numerical Features:
# - **Age**: Most passengers are between 20 and 50 years old.
# - **Flight Distance**: Flights are mostly between 500 and 2000 km.
# - **Seat Comfort**: Ratings mostly between 3 and 4.
#
# ### Categorical Features:
# - **Class**: Most passengers flew in Economy Class.
# - **Customer Type**: The majority are Loyal Customers.
# - **Satisfaction**: The data shows a clear divide between satisfied and dissatisfied passengers.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df_train['Age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Age - Histogram')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_train['Flight Distance'].dropna(), bins=30, color='orange', edgecolor='black')
plt.title('Flight Distance - Histogram')
plt.xlabel('Flight Distance')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_train['Departure Delay in Minutes'].dropna(), bins=30, color='salmon', edgecolor='black')
plt.title('Departure Delay in Minutes - Histogram')
plt.xlabel('Departure Delay (minutes)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_train['Arrival Delay in Minutes'].dropna(), bins=30, color='mediumseagreen', edgecolor='black')
plt.title('Arrival Delay in Minutes - Histogram')
plt.xlabel('Arrival Delay (minutes)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_train['Inflight wifi service'].dropna(), bins=6, color='mediumpurple', edgecolor='black', align='left')
plt.title('Inflight Wifi Service - Histogram')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.xticks(range(6))  # Show scores from 0 to 5
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df_train['Seat comfort'].dropna(), bins=6, color='cornflowerblue', edgecolor='black', align='left')
plt.title('Seat Comfort - Histogram')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.xticks(range(6))  # Show scores from 0 to 5
plt.grid(True)
plt.show()

# %%
gender_counts = df_train['Gender'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(gender_counts.index, gender_counts.values, color='lightcoral', edgecolor='black')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.grid(axis='y')
plt.show()

# %%
customer_counts = df_train['Customer Type'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(customer_counts.index, customer_counts.values, color='mediumslateblue', edgecolor='black')
plt.title('Customer Type Distribution')
plt.xlabel('Customer Type')
plt.ylabel('Number of Passengers')
plt.grid(axis='y')
plt.show()

# %%
travel_type_counts = df_train['Type of Travel'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(travel_type_counts.index, travel_type_counts.values, color='darkorange', edgecolor='black')
plt.title('Type of Travel Distribution')
plt.xlabel('Type of Travel')
plt.ylabel('Number of Passengers')
plt.grid(axis='y')
plt.show()

# %%
# Count the occurrences of each class
class_counts = df_train['Class'].value_counts()

# Plotting the class distribution
plt.figure(figsize=(6, 4))
plt.bar(class_counts.index, class_counts.values, color='lightgreen')
plt.title('Distribution of Travel Classes')
plt.xlabel('Class')
plt.ylabel('Number of Passengers')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Count the number of passengers in each satisfaction category
satisfaction_counts = df_train['satisfaction'].value_counts()

# Plot the satisfaction distribution
plt.figure(figsize=(6, 4))
plt.bar(satisfaction_counts.index, satisfaction_counts.values, color='salmon')
plt.title('Passenger Satisfaction Distribution')
plt.xlabel('Satisfaction Level')
plt.ylabel('Number of Passengers')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(data=df_train, x='satisfaction', y='Inflight wifi service', hue='satisfaction', palette='Set2', dodge=False, legend=False)
plt.title('Inflight Wifi Service by Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Inflight Wifi Service Rating')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(
    data=df_train,
    x='satisfaction',
    y='Ease of Online booking',
    hue='satisfaction',
    palette='Set2',
    dodge=False,
    legend=False
)
plt.title('Satisfaction vs. Ease of Online Booking')
plt.xlabel('Satisfaction')
plt.ylabel('Ease of Online Booking')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Key Findings & Insights
#
# - Features like **Online Boarding**, **Inflight Entertainment**, and **Seat Comfort** strongly influence satisfaction.
# - **Business class** passengers and **loyal customers** are more likely to be satisfied.
# - Areas for improvement include **Inflight Wifi Service** and **Ease of Online Booking** (based on lower ratings).

# %% [markdown]
# ## Conclusion
#
# This exploratory data analysis helped identify the key service areas influencing passenger satisfaction.
# The insights can assist airline companies in enhancing the customer experience and improving loyalty.
